# %%
# %pip install pandas dash
# Out:
# Requirement already satisfied: pandas in C:\Users\joshl\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (3.0.5)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: dash in C:\Users\joshl\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (4.4.1)
# Requirement already satisfied: numpy>=2.3.3 in C:\Users\joshl\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pandas) (2.5.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\Program Files\Positron\resources\app\extensions\positron-python\python_files\lib\ipykernel\py3 (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\joshl\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pandas) (2026.3)
# Requirement already satisfied: Flask<3.2,>=1.0.4 in C:\Users\joshl\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from dash) (3.1.3)
# Requirement already satisfied: Werkzeug<3.2 in C:\Users\joshl\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from dash) (3.1.8)
# Requirement already satisfied: plotly>=5.0.0 in C:\Users\joshl\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from dash) (7.0.0)
# Requirement already satisfied: importlib-metadata in c:\Program Files\Positron\resources\app\extensions\positron-python\python_files\lib\ipykernel\py3 (from dash) (8.7.1)
# Requirement already satisfied: typing_extensions>=4.1.1 in c:\Program Files\Positron\resources\app\extensions\positron-python\python_files\lib\ipykernel\py3 (from dash) (4.15.0)
# Requirement already satisfied: requests in C:\Users\joshl\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from dash) (2.34.2)
# Requirement already satisfied: retrying in C:\Users\joshl\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from dash) (1.4.2)
# Requirement already satisfied: nest-asyncio in c:\Program Files\Positron\resources\app\extensions\positron-python\python_files\lib\ipykernel\py3 (from dash) (1.6.0)
# Requirement already satisfied: setuptools in C:\Users\joshl\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from dash) (84.0.0)
# Requirement already satisfied: janus>=1.0.0 in C:\Users\joshl\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from dash) (2.0.0)
# Requirement already satisfied: pydantic>=2.10 in C:\Users\joshl\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from dash) (2.13.5)
# Requirement already satisfied: comm in c:\Program Files\Positron\resources\app\extensions\positron-python\python_files\lib\ipykernel\py3 (from dash) (0.2.3)
# Requirement already satisfied: blinker>=1.9.0 in C:\Users\joshl\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from Flask<3.2,>=1.0.4->dash) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in C:\Users\joshl\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from Flask<3.2,>=1.0.4->dash) (8.5.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in C:\Users\joshl\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from Flask<3.2,>=1.0.4->dash) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in C:\Users\joshl\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from Flask<3.2,>=1.0.4->dash) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in C:\Users\joshl\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from Flask<3.2,>=1.0.4->dash) (3.0.3)
# Requirement already satisfied: narwhals>=1.15.1 in C:\Users\joshl\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from plotly>=5.0.0->dash) (2.26.0)
# Requirement already satisfied: packaging in c:\Program Files\Positron\resources\app\extensions\positron-python\python_files\lib\ipykernel\py3 (from plotly>=5.0.0->dash) (26.2)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\joshl\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pydantic>=2.10->dash) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.5 in C:\Users\joshl\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pydantic>=2.10->dash) (2.46.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\joshl\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pydantic>=2.10->dash) (0.4.4)
# Requirement already satisfied: six>=1.5 in c:\Program Files\Positron\resources\app\extensions\positron-python\python_files\lib\ipykernel\py3 (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: zipp>=3.20 in c:\Program Files\Positron\resources\app\extensions\positron-python\python_files\lib\ipykernel\py3 (from importlib-metadata->dash) (3.23.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\joshl\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from requests->dash) (3.5.1)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\joshl\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from requests->dash) (3.19)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\joshl\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from requests->dash) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in C:\Users\joshl\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from requests->dash) (2026.7.22)

# %%
#run in terminal

#wget "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/spacex_launch_dash.csv"
#wget "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_3/spacex_dash_app.py"
#spacex_dash_app.py
# Out:
#   Cell In[2], line 1
#
#     wget "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/spacex_launch_dash.csv"
#
#          ^
#
# SyntaxError: invalid syntax
