# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo">
#     </a>
# </p>
#
# <h1 align=center><font size = 5>Assignment: SQL Notebook for Peer Assignment</font></h1>
#
# Estimated time needed: **60** minutes.
#
# ## Introduction
# Using this Python notebook you will:
#
# 1.  Understand the Spacex DataSet
# 2.  Load the dataset  into the corresponding table in a Db2 database
# 3.  Execute SQL queries to answer assignment questions

# %% [markdown]
# ## Overview of the DataSet
#
# SpaceX has gained worldwide attention for a series of historic milestones.
#
# It is the only private company ever to return a spacecraft from low-earth orbit, which it first accomplished in December 2010.
# SpaceX advertises Falcon 9 rocket launches on its website with a cost of 62 million dollars wheras other providers cost upward of 165 million dollars each, much of the savings is because Space X can reuse the first stage.
#
#
# Therefore if we can determine if the first stage will land, we can determine the cost of a launch.
#
# This information can be used if an alternate company wants to bid against SpaceX for a rocket launch.
#
# This dataset includes a record for each payload carried during a SpaceX mission into outer space.

# %% [markdown]
# ### Download the datasets
#
# This assignment requires you to load the spacex dataset.
#
# In many cases the dataset to be analyzed is available as a .CSV (comma separated values) file, perhaps on the internet. Click on the link below to download and save the dataset (.CSV file):
#
#  <a href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_2/data/Spacex.csv" target="_blank">Spacex DataSet</a>

# %%
# !pip install --upgrade sqlalchemy
# Out:
# Requirement already satisfied: sqlalchemy in C:\Users\joshl\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (2.0.52)
# Requirement already satisfied: greenlet>=1 in C:\Users\joshl\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from sqlalchemy) (3.5.5)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\Program Files\Positron\resources\app\extensions\positron-python\python_files\lib\ipykernel\py3 (from sqlalchemy) (4.15.0)

# %% [markdown]
# ### Connect to the database
#
# Let us first load the SQL extension and establish a connection with the database

# %%
# %pip install ipython-sql
# %pip install ipython-sql prettytable
# Out:
# Requirement already satisfied: ipython-sql in C:\Users\joshl\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (0.5.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: prettytable in C:\Users\joshl\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from ipython-sql) (3.18.0)
# Requirement already satisfied: ipython in c:\Program Files\Positron\resources\app\extensions\positron-python\python_files\lib\ipykernel\py3 (from ipython-sql) (8.18.1)
# Requirement already satisfied: sqlalchemy>=2.0 in C:\Users\joshl\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from ipython-sql) (2.0.52)
# Requirement already satisfied: sqlparse in C:\Users\joshl\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from ipython-sql) (0.6.0)
# Requirement already satisfied: six in c:\Program Files\Positron\resources\app\extensions\positron-python\python_files\lib\ipykernel\py3 (from ipython-sql) (1.17.0)
# Requirement already satisfied: ipython-genutils in C:\Users\joshl\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: greenlet>=1 in C:\Users\joshl\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from sqlalchemy>=2.0->ipython-sql) (3.5.5)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\Program Files\Positron\resources\app\extensions\positron-python\python_files\lib\ipykernel\py3 (from sqlalchemy>=2.0->ipython-sql) (4.15.0)
# Requirement already satisfied: decorator in c:\Program Files\Positron\resources\app\extensions\positron-python\python_files\lib\ipykernel\py3 (from ipython->ipython-sql) (5.3.1)
# Requirement already satisfied: jedi>=0.16 in c:\Program Files\Positron\resources\app\extensions\positron-python\python_files\lib\ipykernel\py3 (from ipython->ipython-sql) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\Program Files\Positron\resources\app\extensions\positron-python\python_files\lib\ipykernel\py3 (from ipython->ipython-sql) (0.2.2)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\Program Files\Positron\resources\app\extensions\positron-python\python_files\lib\ipykernel\py3 (from ipython->ipython-sql) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in c:\Program Files\Positron\resources\app\extensions\positron-python\python_files\lib\ipykernel\py3 (from ipython->ipython-sql) (2.20.0)
# Requirement already satisfied: stack-data in c:\Program Files\Positron\resources\app\extensions\positron-python\python_files\lib\ipykernel\py3 (from ipython->ipython-sql) (0.6.3)
# Requirement already satisfied: traitlets>=5 in c:\Program Files\Positron\resources\app\extensions\positron-python\python_files\lib\ipykernel\py3 (from ipython->ipython-sql) (5.15.1)
# Requirement already satisfied: colorama in C:\Users\joshl\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from ipython->ipython-sql) (0.4.6)
# Requirement already satisfied: wcwidth in c:\Program Files\Positron\resources\app\extensions\positron-python\python_files\lib\ipykernel\py3 (from prompt-toolkit<3.1.0,>=3.0.41->ipython->ipython-sql) (0.8.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\Program Files\Positron\resources\app\extensions\positron-python\python_files\lib\ipykernel\py3 (from jedi>=0.16->ipython->ipython-sql) (0.8.7)
# Requirement already satisfied: executing>=1.2.0 in c:\Program Files\Positron\resources\app\extensions\positron-python\python_files\lib\ipykernel\py3 (from stack-data->ipython->ipython-sql) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\Program Files\Positron\resources\app\extensions\positron-python\python_files\lib\ipykernel\py3 (from stack-data->ipython->ipython-sql) (3.0.1)
# Requirement already satisfied: pure-eval in c:\Program Files\Positron\resources\app\extensions\positron-python\python_files\lib\ipykernel\py3 (from stack-data->ipython->ipython-sql) (0.2.3)
# Requirement already satisfied: ipython-sql in C:\Users\joshl\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (0.5.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: prettytable in C:\Users\joshl\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (3.18.0)
# Requirement already satisfied: ipython in c:\Program Files\Positron\resources\app\extensions\positron-python\python_files\lib\ipykernel\py3 (from ipython-sql) (8.18.1)
# Requirement already satisfied: sqlalchemy>=2.0 in C:\Users\joshl\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from ipython-sql) (2.0.52)
# Requirement already satisfied: sqlparse in C:\Users\joshl\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from ipython-sql) (0.6.0)
# Requirement already satisfied: six in c:\Program Files\Positron\resources\app\extensions\positron-python\python_files\lib\ipykernel\py3 (from ipython-sql) (1.17.0)
# Requirement already satisfied: ipython-genutils in C:\Users\joshl\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: wcwidth>=0.3.5 in c:\Program Files\Positron\resources\app\extensions\positron-python\python_files\lib\ipykernel\py3 (from prettytable) (0.8.1)
# Requirement already satisfied: greenlet>=1 in C:\Users\joshl\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from sqlalchemy>=2.0->ipython-sql) (3.5.5)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\Program Files\Positron\resources\app\extensions\positron-python\python_files\lib\ipykernel\py3 (from sqlalchemy>=2.0->ipython-sql) (4.15.0)
# Requirement already satisfied: decorator in c:\Program Files\Positron\resources\app\extensions\positron-python\python_files\lib\ipykernel\py3 (from ipython->ipython-sql) (5.3.1)
# Requirement already satisfied: jedi>=0.16 in c:\Program Files\Positron\resources\app\extensions\positron-python\python_files\lib\ipykernel\py3 (from ipython->ipython-sql) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\Program Files\Positron\resources\app\extensions\positron-python\python_files\lib\ipykernel\py3 (from ipython->ipython-sql) (0.2.2)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\Program Files\Positron\resources\app\extensions\positron-python\python_files\lib\ipykernel\py3 (from ipython->ipython-sql) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in c:\Program Files\Positron\resources\app\extensions\positron-python\python_files\lib\ipykernel\py3 (from ipython->ipython-sql) (2.20.0)
# Requirement already satisfied: stack-data in c:\Program Files\Positron\resources\app\extensions\positron-python\python_files\lib\ipykernel\py3 (from ipython->ipython-sql) (0.6.3)
# Requirement already satisfied: traitlets>=5 in c:\Program Files\Positron\resources\app\extensions\positron-python\python_files\lib\ipykernel\py3 (from ipython->ipython-sql) (5.15.1)
# Requirement already satisfied: colorama in C:\Users\joshl\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from ipython->ipython-sql) (0.4.6)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\Program Files\Positron\resources\app\extensions\positron-python\python_files\lib\ipykernel\py3 (from jedi>=0.16->ipython->ipython-sql) (0.8.7)
# Requirement already satisfied: executing>=1.2.0 in c:\Program Files\Positron\resources\app\extensions\positron-python\python_files\lib\ipykernel\py3 (from stack-data->ipython->ipython-sql) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\Program Files\Positron\resources\app\extensions\positron-python\python_files\lib\ipykernel\py3 (from stack-data->ipython->ipython-sql) (3.0.1)
# Requirement already satisfied: pure-eval in c:\Program Files\Positron\resources\app\extensions\positron-python\python_files\lib\ipykernel\py3 (from stack-data->ipython->ipython-sql) (0.2.3)

# %%
# %load_ext sql

# %%
import csv, sqlite3
import prettytable
prettytable.DEFAULT = 'DEFAULT'

con = sqlite3.connect("my_data1.db")
cur = con.cursor()

# %%
# !pip install -q pandas

# %%
# %sql sqlite:///my_data1.db

# %%
import pandas as pd
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_2/data/Spacex.csv")
df.to_sql("SPACEXTBL", con, if_exists='replace', index=False,method="multi")
# Out:
# 101

# %% [markdown]
# **Note:This below code is added to remove blank rows from table**

# %%
#DROP THE TABLE IF EXISTS

# %sql DROP TABLE IF EXISTS SPACEXTABLE;
# Out:
#  * sqlite:///my_data1.db
# Done.
# []

# %%
# %sql create table SPACEXTABLE as select * from SPACEXTBL where Date is not null
# Out:
#  * sqlite:///my_data1.db
# Done.
# []

# %% [markdown]
# ## Tasks
#
# Now write and execute SQL queries to solve the assignment tasks.
#
# **Note: If the column names are in mixed case enclose it in double quotes
#    For Example "Landing_Outcome"**
#
# ### Task 1
#
#
#
#
# ##### Display the names of the unique launch sites  in the space mission

# %%
cur.execute(
    'select distinct "Launch_Site" from SPACEXTBL'
)
results = cur.fetchall()
print(results)
# Out:
# [('CCAFS LC-40',), ('VAFB SLC-4E',), ('KSC LC-39A',), ('CCAFS SLC-40',)]

# %% [markdown]
# ### Task 2
#
#
# #####  Display 5 records where launch sites begin with the string 'CCA'

# %%
cur.execute('select * from SPACEXTBL where "Launch_Site" like "CCA%" limit 5')
results2 = cur.fetchall()
df2 = pd.DataFrame(results2)
print(df2)
# Out:
#             0         1               2            3  \
# 0  2010-06-04  18:45:00  F9 v1.0  B0003  CCAFS LC-40
# 1  2010-12-08  15:43:00  F9 v1.0  B0004  CCAFS LC-40
# 2  2012-05-22   7:44:00  F9 v1.0  B0005  CCAFS LC-40
# 3  2012-10-08   0:35:00  F9 v1.0  B0006  CCAFS LC-40
# 4  2013-03-01  15:10:00  F9 v1.0  B0007  CCAFS LC-40
#
#                                                    4    5          6  \
# 0               Dragon Spacecraft Qualification Unit    0        LEO
# 1  Dragon demo flight C1, two CubeSats, barrel of...    0  LEO (ISS)
# 2                              Dragon demo flight C2  525  LEO (ISS)
# 3                                       SpaceX CRS-1  500  LEO (ISS)
# 4                                       SpaceX CRS-2  677  LEO (ISS)
#
#                  7        8                    9
# 0           SpaceX  Success  Failure (parachute)
# 1  NASA (COTS) NRO  Success  Failure (parachute)
# 2      NASA (COTS)  Success           No attempt
# 3       NASA (CRS)  Success           No attempt
# 4       NASA (CRS)  Success           No attempt

# %% [markdown]
# ### Task 3
#
#
#
#
# ##### Display the total payload mass carried by boosters launched by NASA (CRS)

# %%
import textwrap

# %%
query = textwrap.dedent("""
select sum(PAYLOAD_MASS__KG_)
from SPACEXTBL
where customer = "NASA (CRS)"
""")
cur.execute(query)
results3 = cur.fetchall()
df3 = pd.DataFrame(results3)
print(df3)
# Out:
#        0
# 0  45596

# %% [markdown]
# ### Task 4
#
#
#
#
# ##### Display average payload mass carried by booster version F9 v1.1

# %%
query = textwrap.dedent("""
select avg(PAYLOAD_MASS__KG_)
from SPACEXTBL
where Booster_Version like "F9 v1.1%"
""")
cur.execute(query)
results4 = cur.fetchall()
df4 = pd.DataFrame(results4)
print(df4)
# Out:
#              0
# 0  2534.666667

# %% [markdown]
# ### Task 5
#
# ##### List the date when the first succesful landing outcome in ground pad was acheived.
#
#
# _Hint:Use min function_

# %%
query = textwrap.dedent("""
select min(date)
from SPACEXTBL
where Landing_Outcome = "Success (ground pad)"
""")
cur.execute(query)
results4 = cur.fetchall()
df4 = pd.DataFrame(results4)
print(df4)
# Out:
#             0
# 0  2015-12-22

# %% [markdown]
# ### Task 6
#
# ##### List the names of the boosters which have success in drone ship and have payload mass greater than 4000 but less than 6000

# %%
query = textwrap.dedent("""
select distinct Booster_Version
from SPACEXTBL
where Landing_Outcome = "Success (drone ship)" AND
PAYLOAD_MASS__KG_ between 4000 and 6000
""")
cur.execute(query)
results4 = cur.fetchall()
df4 = pd.DataFrame(results4)
print(df4)
# Out:
#                 0
# 0     F9 FT B1022
# 1     F9 FT B1026
# 2  F9 FT  B1021.2
# 3  F9 FT  B1031.2

# %% [markdown]
# ### Task 7
#
#
#
#
# ##### List the total number of successful and failure mission outcomes

# %%
query = textwrap.dedent("""
select distinct Mission_Outcome, count(*)
from SPACEXTBL
group by Mission_Outcome
""")
cur.execute(query)
results4 = cur.fetchall()
df4 = pd.DataFrame(results4)
print(df4)
# Out:
#                                   0   1
# 0               Failure (in flight)   1
# 1                           Success  98
# 2                          Success    1
# 3  Success (payload status unclear)   1

# %% [markdown]
# ### Task 8
#
#
#
# ##### List all the booster_versions that have carried the maximum payload mass, using a subquery with a suitable aggregate function.

# %%
query = textwrap.dedent("""
select Booster_Version
from SPACEXTBL
where PAYLOAD_MASS__KG_ = (
select max(payload_mass__kg_)
from SPACEXTBL
)
""")
cur.execute(query)
results4 = cur.fetchall()
df4 = pd.DataFrame(results4)
print(df4)
# Out:
#                  0
# 0    F9 B5 B1048.4
# 1    F9 B5 B1049.4
# 2    F9 B5 B1051.3
# 3    F9 B5 B1056.4
# 4    F9 B5 B1048.5
# 5    F9 B5 B1051.4
# 6    F9 B5 B1049.5
# 7   F9 B5 B1060.2
# 8   F9 B5 B1058.3
# 9    F9 B5 B1051.6
# 10   F9 B5 B1060.3
# 11  F9 B5 B1049.7

# %% [markdown]
# ### Task 9
#
#
# ##### List the records which will display the month names, failure landing_outcomes in drone ship ,booster versions, launch_site for the months in year 2015.
#
# **Note: SQLLite does not support monthnames. So you need to use  substr(Date, 6,2) as month to get the months and substr(Date,0,5)='2015' for year.**

# %%
query = textwrap.dedent("""
select substr(Date, 6,2) as month, Landing_Outcome, Booster_Version, Launch_Site
from SPACEXTBL
where Landing_Outcome = "Failure (drone ship)" and
substr(Date,0,5) = "2015"
""")
cur.execute(query)
results4 = cur.fetchall()
df4 = pd.DataFrame(results4)
print(df4)
# Out:
#     0                     1              2            3
# 0  01  Failure (drone ship)  F9 v1.1 B1012  CCAFS LC-40
# 1  04  Failure (drone ship)  F9 v1.1 B1015  CCAFS LC-40

# %% [markdown]
# ### Task 10
#
#
#
#
# ##### Rank the count of landing outcomes (such as Failure (drone ship) or Success (ground pad)) between the date 2010-06-04 and 2017-03-20, in descending order.

# %%
query = textwrap.dedent("""
select distinct(Landing_Outcome), count(*) as count
from SPACEXTBL
where date between "2010-06-04" and "2017-03-20"
group by Landing_Outcome
order by count desc
""")
cur.execute(query)
results4 = cur.fetchall()
df4 = pd.DataFrame(results4)
print(df4)
# Out:
#                         0   1
# 0              No attempt  10
# 1    Success (drone ship)   5
# 2    Failure (drone ship)   5
# 3    Success (ground pad)   3
# 4      Controlled (ocean)   3
# 5    Uncontrolled (ocean)   2
# 6     Failure (parachute)   2
# 7  Precluded (drone ship)   1

# %% [markdown]
# ### Reference Links
#
# * <a href ="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Labs_Coursera_V5/labs/Lab%20-%20String%20Patterns%20-%20Sorting%20-%20Grouping/instructional-labs.md.html?origin=www.coursera.org">Hands-on Lab : String Patterns, Sorting and Grouping</a>
#
# *  <a  href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Labs_Coursera_V5/labs/Lab%20-%20Built-in%20functions%20/Hands-on_Lab__Built-in_Functions.md.html?origin=www.coursera.org">Hands-on Lab: Built-in functions</a>
#
# *  <a  href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Labs_Coursera_V5/labs/Lab%20-%20Sub-queries%20and%20Nested%20SELECTs%20/instructional-labs.md.html?origin=www.coursera.org">Hands-on Lab : Sub-queries and Nested SELECT Statements</a>
#
# *   <a href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Module%205/DB0201EN-Week3-1-3-SQLmagic.ipynb">Hands-on Tutorial: Accessing Databases with SQL magic</a>
#
# *  <a href= "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Module%205/DB0201EN-Week3-1-4-Analyzing.ipynb">Hands-on Lab: Analyzing a real World Data Set</a>

# %% [markdown]
# ## Author(s)
#
# <h4> Lakshmi Holla </h4>

# %% [markdown]
# ## Other Contributors
#
# <h4> Rav Ahuja </h4>

# %% [markdown]
# <!--
# ## Change log
# | Date | Version | Changed by | Change Description |
# |------|--------|--------|---------|
# | 2024-07-10 | 1.1 |Anita Verma | Changed Version|
# | 2021-07-09 | 0.2 |Lakshmi Holla | Changes made in magic sql|
# | 2021-05-20 | 0.1 |Lakshmi Holla | Created Initial Version |
# -->

# %% [markdown]
# ## <h3 align="center"> © IBM Corporation 2021. All rights reserved. <h3/>
